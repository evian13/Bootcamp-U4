# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score

from sklearn import ensemble

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import accuracy_score

from sklearn.model_selection import GridSearchCV

from sklearn.feature_selection import SelectKBest

# %% [markdown]
# Let's build a neural network. We will have multiple features we feed into our model, each of which will go through a set of perceptron models to arrive at a response which will be trained to our output.
#
# Like many models we've covered, this can be used as both a regression or classification model.
#
# First, we need to load our dataset. For this example we'll use The Museum of Modern Art in New York's [public dataset](https://media.githubusercontent.com/media/MuseumofModernArt/collection/master/Artworks.csv) on their collection.

# %%
# artworks = pd.read_csv('https://media.githubusercontent.com/media/MuseumofModernArt/collection/master/Artworks.csv')
# Save the downloaded file to csv:
# artworks.to_csv('artworks' , sep = ',' , index =False)


artworks = pd.read_csv('U4L3.3_artworks.csv'  )

# %%
artworks
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria, Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# 5       The Manhattan Transcripts Project, New York, N...
# 6       The Manhattan Transcripts Project, New York, N...
# 7       The Manhattan Transcripts Project, New York, N...
# 8       The Manhattan Transcripts Project, New York, N...
# 9       The Manhattan Transcripts Project, New York, N...
# 10      The Manhattan Transcripts Project, New York, N...
# 11      The Manhattan Transcripts Project, New York, N...
# 12      The Manhattan Transcripts Project, New York, N...
# 13      The Manhattan Transcripts Project, New York, N...
# 14      The Manhattan Transcripts Project, New York, N...
# 15      The Manhattan Transcripts Project, New York, N...
# 16      The Manhattan Transcripts Project, New York, N...
# 17      The Manhattan Transcripts Project, New York, N...
# 18      The Manhattan Transcripts Project, New York, N...
# 19      The Manhattan Transcripts Project, New York, N...
# 20      The Manhattan Transcripts Project, New York, N...
# 21      The Manhattan Transcripts Project, New York, N...
# 22      The Manhattan Transcripts Project, New York, N...
# 23      The Manhattan Transcripts Project, New York, N...
# 24      The Manhattan Transcripts Project, New York, N...
# 25      The Manhattan Transcripts Project, New York, N...
# 26      The Manhattan Transcripts Project, New York, N...
# 27      The Manhattan Transcripts Project, New York, N...
# 28      The Manhattan Transcripts Project, New York, N...
# 29      The Manhattan Transcripts Project, New York, N...
# ...                                                   ...
# 152546  National Life Insurance Company Building, Chic...
# 152547  St. Mark's Tower in the Bouwerie, project, New...
# 152548  St. Mark's Tower in the Bouwerie, project, New...
# 152549  St. Mark's Tower in the Bouwerie, project, New...
# 152550  IIT Commons Building, Chicago, IL (Plans, elev...
# 152551         Solomon R. Guggenheim Museum, New York, NY
# 152552         Solomon R. Guggenheim Museum, New York, NY
# 152553         Solomon R. Guggenheim Museum, New York, NY
# 152554         Solomon R. Guggenheim Museum, New York, NY
# 152555         Solomon R. Guggenheim Museum, New York, NY
# 152556         Solomon R. Guggenheim Museum, New York, NY
# 152557         Solomon R. Guggenheim Museum, New York, NY
# 152558         Solomon R. Guggenheim Museum, New York, NY
# 152559         Solomon R. Guggenheim Museum, New York, NY
#
#                                                    Medium       ...        \
# 0           Ink and cut-and-pasted painted pages on paper       ...
# 1                       Paint and colored pencil on print       ...
# 2       Graphite, pen, color pencil, ink, and gouache ...       ...
# 3       Photographic reproduction with colored synthet...       ...
# 4       Graphite, color pencil, ink, and gouache on tr...       ...
# 5                               Gelatin silver photograph       ...
# 6                              Gelatin silver photographs       ...
# 7                               Gelatin silver photograph       ...
# 8                               Gelatin silver photograph       ...
# 9                               Gelatin silver photograph       ...
# 10                              Gelatin silver photograph       ...
# 11                              Gelatin silver photograph       ...
# 12                              Gelatin silver photograph       ...
# 13                              Gelatin silver photograph       ...
# 14                              Gelatin silver photograph       ...
# 15                              Gelatin silver photograph       ...
# 16                              Gelatin silver photograph       ...
# 17                              Gelatin silver photograph       ...
# 18                              Gelatin silver photograph       ...
# 19                              Gelatin silver photograph       ...
# 20                              Gelatin silver photograph       ...
# 21                              Gelatin silver photograph       ...
# 22                              Gelatin silver photograph       ...
# 23                              Gelatin silver photograph       ...
# 24                              Gelatin silver photograph       ...
# 25                              Gelatin silver photograph       ...
# 26                              Gelatin silver photograph       ...
# 27                              Gelatin silver photograph       ...
# 28                              Gelatin silver photograph       ...
# 29                              Gelatin silver photograph       ...
# ...                                                   ...       ...
# 152546                                                NaN       ...
# 152547                                                NaN       ...
# 152548                                                NaN       ...
# 152549                                                NaN       ...
# 152550                        Colored pencil on blueprint       ...
# 152551                                                NaN       ...
# 152552                                                NaN       ...
# 152553                                                NaN       ...
# 152554                                                NaN       ...
# 152555                                                NaN       ...
# 152556                                                NaN       ...
# 152557                                                NaN       ...
# 152558                                                NaN       ...
# 152559                                                NaN       ...
# 152560                                                NaN       ...
# 152561                                                NaN       ...
# 152562                                                NaN       ...
# 152563                                                NaN       ...
# 152564                                                NaN       ...
# 152565                                                NaN       ...
# 152566                                                NaN       ...
# 152567                                                NaN       ...
# 152568                                                NaN       ...
# 152569                                                NaN       ...
# 152570                                                NaN       ...
# 152571                                                NaN       ...
# 152572                                                NaN       ...
# 152573                                                NaN       ...
# 152574                                            Drawing       ...
# 152575                                            Drawing       ...
#
#                                              ThumbnailURL Circumference (cm)  \
# 0       http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...                NaN
# 1       http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...                NaN
# 2       http://www.moma.org/media/W1siZiIsIjk4Il0sWyJw...                NaN
# 3       http://www.moma.org/media/W1siZiIsIjEyNCJdLFsi...                NaN
# 4       http://www.moma.org/media/W1siZiIsIjEyNiJdLFsi...                NaN
# 5       http://www.moma.org/media/W1siZiIsIjE0OCJdLFsi...                NaN
# 6       http://www.moma.org/media/W1siZiIsIjE0OSJdLFsi...                NaN
# 7       http://www.moma.org/media/W1siZiIsIjE0OSJdLFsi...                NaN
# 8       http://www.moma.org/media/W1siZiIsIjE1MCJdLFsi...                NaN
# 9       http://www.moma.org/media/W1siZiIsIjE1MSJdLFsi...                NaN
# 10      http://www.moma.org/media/W1siZiIsIjE1MyJdLFsi...                NaN
# 11      http://www.moma.org/media/W1siZiIsIjE1NCJdLFsi...                NaN
# 12      http://www.moma.org/media/W1siZiIsIjE1NSJdLFsi...                NaN
# 13      http://www.moma.org/media/W1siZiIsIjE1NiJdLFsi...                NaN
# 14      http://www.moma.org/media/W1siZiIsIjE1NyJdLFsi...                NaN
# 15      http://www.moma.org/media/W1siZiIsIjE1OCJdLFsi...                NaN
# 16      http://www.moma.org/media/W1siZiIsIjE1OSJdLFsi...                NaN
# 17      http://www.moma.org/media/W1siZiIsIjE2MCJdLFsi...                NaN
# 18      http://www.moma.org/media/W1siZiIsIjE2MSJdLFsi...                NaN
# 19      http://www.moma.org/media/W1siZiIsIjE2MiJdLFsi...                NaN
# 20      http://www.moma.org/media/W1siZiIsIjE2MyJdLFsi...                NaN
# 21      http://www.moma.org/media/W1siZiIsIjE2NCJdLFsi...                NaN
# 22      http://www.moma.org/media/W1siZiIsIjE2NSJdLFsi...                NaN
# 23      http://www.moma.org/media/W1siZiIsIjE2NiJdLFsi...                NaN
# 24      http://www.moma.org/media/W1siZiIsIjE2NyJdLFsi...                NaN
# 25      http://www.moma.org/media/W1siZiIsIjE2OCJdLFsi...                NaN
# 26      http://www.moma.org/media/W1siZiIsIjE2OSJdLFsi...                NaN
# 27      http://www.moma.org/media/W1siZiIsIjE3MCJdLFsi...                NaN
# 28      http://www.moma.org/media/W1siZiIsIjE3MSJdLFsi...                NaN
# 29      http://www.moma.org/media/W1siZiIsIjE3MiJdLFsi...                NaN
# ...                                                   ...                ...
# 152546                                                NaN                NaN
# 152547                                                NaN                NaN
# 152548                                                NaN                NaN
# 152549                                                NaN                NaN
# 152550                                                NaN                NaN
# 152551                                                NaN                NaN
# 152552                                                NaN                NaN
# 152553                                                NaN                NaN
# 152554                                                NaN                NaN
# 152555                                                NaN                NaN
# 152556                                                NaN                NaN
# 152557                                                NaN                NaN
# 152558                                                NaN                NaN
# 152559                                                NaN                NaN
# 152560                                                NaN                NaN
# 152561                                                NaN                NaN
# 152562                                                NaN                NaN
# 152563                                                NaN                NaN
# 152564                                                NaN                NaN
# 152565                                                NaN                NaN
# 152566                                                NaN                NaN
# 152567                                                NaN                NaN
# 152568                                                NaN                NaN
# 152569                                                NaN                NaN
# 152570                                                NaN                NaN
# 152571                                                NaN                NaN
# 152572                                                NaN                NaN
# 152573                                                NaN                NaN
# 152574                                                NaN                NaN
# 152575                                                NaN                NaN
#
#        Depth (cm) Diameter (cm) Height (cm) Length (cm) Weight (kg)  \
# 0             NaN           NaN   48.600000         NaN         NaN
# 1             NaN           NaN   40.640100         NaN         NaN
# 2             NaN           NaN   34.300000         NaN         NaN
# 3             NaN           NaN   50.800000         NaN         NaN
# 4             NaN           NaN   38.400000         NaN         NaN
# 5             NaN           NaN   35.600000         NaN         NaN
# 6             NaN           NaN   35.600000         NaN         NaN
# 7             NaN           NaN   35.600000         NaN         NaN
# 8        45.700000              NaN             NaN
# 9        45.700000              NaN             NaN
# 10       45.700000              NaN             NaN
# 11       45.700000              NaN             NaN
# 12       45.700000              NaN             NaN
# 13       45.700000              NaN             NaN
# 14       45.700000              NaN             NaN
# 15       45.700000              NaN             NaN
# 16       45.700000              NaN             NaN
# 17       45.700000              NaN             NaN
# 18       45.700000              NaN             NaN
# 19       45.700000              NaN             NaN
# 20       45.700000              NaN             NaN
# 21       45.700000              NaN             NaN
# 22       45.700000              NaN             NaN
# 23       45.700000              NaN             NaN
# 24       45.700000              NaN             NaN
# 25       45.700000              NaN             NaN
# 26       45.700000              NaN             NaN
# 27       45.700000              NaN             NaN
# 28       45.700000              NaN             NaN
# 29       45.700000              NaN             NaN
# ...            ...              ...             ...
# 152546   42.862586              NaN             NaN
# 152547   59.055118              NaN             NaN
# 152548   59.055118              NaN             NaN
# 152549   59.055118              NaN             NaN
# 152550   88.900178              NaN             NaN
# 152551   98.425197              NaN             NaN
# 152552   91.440183              NaN             NaN
# 152553   91.440183              NaN             NaN
# 152554  101.600203              NaN             NaN
# 152555  101.600203              NaN             NaN
# 152556  101.600203              NaN             NaN
# 152557  101.600203              NaN             NaN
# 152558   91.440183              NaN             NaN
# 152559   91.440183              NaN             NaN
# 152560   91.440183              NaN             NaN
# 152561   91.440183              NaN             NaN
# 152562   68.580137              NaN             NaN
# 152563   68.580137              NaN             NaN
# 152564  101.600203              NaN             NaN
# 152565   91.440183              NaN             NaN
# 152566  121.920244              NaN             NaN
# 152567   91.440183              NaN             NaN
# 152568   91.440183              NaN             NaN
# 152569   91.440183              NaN             NaN
# 152570   91.440183              NaN             NaN
# 152571   88.900178              NaN             NaN
# 152572   88.900178              NaN             NaN
# 152573   91.440183              NaN             NaN
# 152574         NaN              NaN             NaN
# 152575         NaN              NaN             NaN
#
# [152576 rows x 29 columns]

# %%
artworks.shape
# Out:
# (152576, 29)

# %%
artworks.columns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'ArtistBio', 'Nationality',
#        'BeginDate', 'EndDate', 'Gender', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ThumbnailURL',
#        'Circumference (cm)', 'Depth (cm)', 'Diameter (cm)', 'Height (cm)',
#        'Length (cm)', 'Weight (kg)', 'Width (cm)', 'Seat Height (cm)',
#        'Duration (sec.)'],
#       dtype='object')

# %% [markdown]
# We'll also do a bit of data processing and cleaning, selecting columns of interest and converting URL's to booleans indicating whether they are present.

# %%
# Display first 3 values to peek in:
artworks['URL'].value_counts(dropna=False)[:3]
# Out:
# NaN                                           74928
# http://www.moma.org/collection/works/84024        1
# http://www.moma.org/collection/works/91329        1
# Name: URL, dtype: int64

# %% [markdown]
# There are a lot of missing values!

# %%
# Display first 5 values to peek in:
artworks['ThumbnailURL'].value_counts(dropna=False)[:5]
# Out:
# NaN                                                                                                                               85452
# http://www.moma.org/media/W1siZiIsIjE5OTkxNCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=cabab63ac5a7d402       59
# http://www.moma.org/media/W1siZiIsIjEzNjMxNSJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=fbf6ad0392f98ee3       28
# http://www.moma.org/media/W1siZiIsIjIzMDI1NyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=1ef42de47aa2e7fb       11
# http://www.moma.org/media/W1siZiIsIjIyODM1MyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=a1619cfbf3adbe4e        9
# Name: ThumbnailURL, dtype: int64

# %%
artworks['Department'].value_counts(dropna=False)
# Out:
# Prints & Illustrated Books               62017
# Photography                              30327
# Architecture & Design                    19166
# NaN                                      17169
# Drawings                                 11498
# Painting & Sculpture                      3812
# Film                                      3759
# Media and Performance Art                 2736
# Fluxus Collection                         2070
# Architecture & Design - Image Archive       22
# Name: Department, dtype: int64

# %%
# Select Columns.
artworks = artworks[['Artist', 'Nationality', 'Gender', 'Date', 'Department',
                    'DateAcquired', 'URL', 'ThumbnailURL', 'Height (cm)', 'Width (cm)']]

# Convert URL's to booleans.
artworks['URL'] = artworks['URL'].notnull()
artworks['ThumbnailURL'] = artworks['ThumbnailURL'].notnull()

# Drop films and some other tricky rows.
artworks = artworks[artworks['Department']!='Film']
artworks = artworks[artworks['Department']!='Media and Performance Art']
artworks = artworks[artworks['Department']!='Fluxus Collection']

# Drop missing data.
artworks = artworks.dropna()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print(artworks.shape)
artworks.head()
# Out:
# (105817, 10)
#                      Artist Nationality  Gender  Date             Department  \
# 0               Otto Wagner  (Austrian)  (Male)  1896  Architecture & Design
# 1  Christian de Portzamparc    (French)  (Male)  1987  Architecture & Design
# 2                Emil Hoppe  (Austrian)  (Male)  1903  Architecture & Design
# 3           Bernard Tschumi          ()  (Male)  1980  Architecture & Design
# 4                Emil Hoppe  (Austrian)  (Male)  1903  Architecture & Design
#
#   DateAcquired   URL  ThumbnailURL  Height (cm)  Width (cm)
# 0   1996-04-09  True          True      48.6000    168.9000
# 1   1995-01-17  True          True      40.6401     29.8451
# 2   1997-01-15  True          True      34.3000     31.8000
# 3   1995-01-17  True          True      50.8000     50.8000
# 4   1997-01-15  True          True      38.4000     19.1000

# %% [markdown]
# ## Building a Model
#
# Now, let's see if we can use multi-layer perceptron modeling (or "MLP") to see if we can classify the department a piece should go into using everything but the department name.
#
# Before we import MLP from SKLearn and establish the model we first have to ensure correct typing for our data and do some other cleaning.

# %%
# Get data types.
artworks.dtypes
# Out:
# Artist           object
# Nationality      object
# Gender           object
# Date             object
# Department       object
# DateAcquired     object
# URL                bool
# ThumbnailURL       bool
# Height (cm)     float64
# Width (cm)      float64
# dtype: object

# %% [markdown]
# The `DateAcquired` column is an object. Let's transform that to a datetime object and add a feature for just the year the artwork was acquired.

# %%
artworks['DateAcquired'] = pd.to_datetime(artworks.DateAcquired)
artworks['YearAcquired'] = artworks.DateAcquired.dt.year
artworks['YearAcquired'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# 152221              Sou Fujimoto, Sou Fujimoto Architects
# 152222              Sou Fujimoto, Sou Fujimoto Architects
# 152223              Sou Fujimoto, Sou Fujimoto Architects
# 152224              Sou Fujimoto, Sou Fujimoto Architects
# 152225              Sou Fujimoto, Sou Fujimoto Architects
# 152226              Sou Fujimoto, Sou Fujimoto Architects
# 152227              Sou Fujimoto, Sou Fujimoto Architects
# 152228              Sou Fujimoto, Sou Fujimoto Architects
# 152229              Sou Fujimoto, Sou Fujimoto Architects
# 152230              Sou Fujimoto, Sou Fujimoto Architects
# 152231              Sou Fujimoto, Sou Fujimoto Architects
# 152232              Sou Fujimoto, Sou Fujimoto Architects
# 152233              Sou Fujimoto, Sou Fujimoto Architects
# 152234              Sou Fujimoto, Sou Fujimoto Architects
# 152235              Sou Fujimoto, Sou Fujimoto Architects
# 152236              Sou Fujimoto, Sou Fujimoto Architects
# 152237              Sou Fujimoto, Sou Fujimoto Architects
# 152238              Sou Fujimoto, Sou Fujimoto Architects
# 152239              Sou Fujimoto, Sou Fujimoto Architects
#
#                                               Nationality  \
# 65                                          (American) ()
# 66                                        (Dutch) (Dutch)
# 76                          (Italian) (Italian) (Italian)
# 107                                   (Swedish) (Swedish)
# 110                        (American) (French) (American)
# 111                        (American) (French) (American)
# 112                        (American) (American) (French)
# 113                        (American) (French) (American)
# 151                      (American) (American) (American)
# 154                   (Dutch) (British) (British) (Dutch)
# 160                      (American) (American) (American)
# 161           (American) (American) (American) (American)
# 162           (American) (American) (American) (American)
# 163           (American) (American) (American) (American)
# 164           (American) (American) (American) (American)
# 178                                       (Dutch) (Dutch)
# 195                               (Brazilian) (Brazilian)
# 196                               (Brazilian) (Brazilian)
# 238                                 (American) (American)
# 240                                 (American) (American)
# 241                              () (American) (American)
# 242                   (Dutch) (British) (British) (Dutch)
# 253                                   (Swedish) (Swedish)
# 254                         (Italian) (Italian) (Italian)
# 266                         (Italian) (Italian) (Italian)
# 267                         (Italian) (Italian) (Italian)
# 268     (Italian) (Italian) (Italian) (Italian) (Italian)
# 320                   (Dutch) (British) (Dutch) (British)
# 322                   (Dutch) (British) (Dutch) (British)
# 329                   (Dutch) (British) (Dutch) (British)
# ...                                                   ...
# 152210                                      (Japanese) ()
# 152211                                      (Japanese) ()
# 152212                                      (Japanese) ()
# 152213                                      (Japanese) ()
# 152214                                      (Japanese) ()
# 152215                                      (Japanese) ()
# 152216                                      (Japanese) ()
# 152217                                      (Japanese) ()
# 152218                                      (Japanese) ()
# 152219                                      (Japanese) ()
# 152220                                      (Japanese) ()
# 152221                                      (Japanese) ()
# 152222                                      (Japanese) ()
# 152223                                      (Japanese) ()
# 152224                                      (Japanese) ()
# 152225                                      (Japanese) ()
# 152226                                      (Japanese) ()
# 152227                                      (Japanese) ()
# 152228                                      (Japanese) ()
# 152229                                      (Japanese) ()
# 152230                                      (Japanese) ()
# 152231                                      (Japanese) ()
# 152232                                      (Japanese) ()
# 152233                                      (Japanese) ()
# 152234                                      (Japanese) ()
# 152235                                      (Japanese) ()
# 152236                                      (Japanese) ()
# 152237                                      (Japanese) ()
# 152238                                      (Japanese) ()
# 152239                                      (Japanese) ()
#
#                                     Gender         Date  \
# 65                           (Male) (Male)         1975
# 66                         (Male) (Female)         1987
# 76                    (Male) (Male) (Male)         1974
# 107                          (Male) (Male)         1937
# 110                   (Male) (Male) (Male)         1938
# 111                   (Male) (Male) (Male)         1938
# 112                   (Male) (Male) (Male)         1938
# 113                   (Male) (Male) (Male)         1938
# 151                     () (Female) (Male)         1989
# 154        (Male) (Female) (Male) (Female)         1975
# 160                       () (Male) (Male)         1965
# 161              () (Male) (Male) (Female)         1978
# 162              () (Male) (Male) (Female)         1981
# 163              () (Male) (Male) (Female)         1981
# 164              () (Male) (Male) (Female)         1983
# 178                          (Male) (Male)         1923
# 195                          (Male) (Male)         1953
# 196                          (Male) (Male)         1953
# 238                          (Male) (Male)         1987
# 240                          (Male) (Male)         1987
# 241                       () (Male) (Male)         1990
# 242        (Male) (Male) (Female) (Female)         1981
# 253                          (Male) (Male)  c.1918-1920
# 254                   (Male) (Male) (Male)         1939
# 266                   (Male) (Male) (Male)         1938
# 267                   (Male) (Male) (Male)         1938
# 268     (Male) (Male) (Male) (Male) (Male)         1938
# 320        (Male) (Male) (Female) (Female)         1972
# 322        (Male) (Male) (Female) (Female)         1972
# 329        (Male) (Male) (Female) (Female)         1972
# ...                                    ...          ...
# 152210                           (Male) ()         2015
# 152211                           (Male) ()         2015
# 152212                           (Male) ()         2015
# 152213                           (Male) ()         2015
# 152214                           (Male) ()         2015
# 152215                           (Male) ()         2015
# 152216                           (Male) ()         2015
# 152217                           (Male) ()         2015
# 152218                           (Male) ()         2015
# 152219                           (Male) ()         2015
# 152220                           (Male) ()         2015
# 152221                           (Male) ()         2015
# 152222                           (Male) ()         2015
# 152223                           (Male) ()         2015
# 152224                           (Male) ()         2015
# 152225                           (Male) ()         2015
# 152226                           (Male) ()         2015
# 152227                           (Male) ()         2015
# 152228                           (Male) ()         2015
# 152229                           (Male) ()         2015
# 152230                           (Male) ()         2015
# 152231                           (Male) ()         2015
# 152232                           (Male) ()         2015
# 152233                           (Male) ()         2015
# 152234                           (Male) ()         2015
# 152235                           (Male) ()         2015
# 152236                           (Male) ()         2015
# 152237                           (Male) ()         2015
# 152238                           (Male) ()         2015
# 152239                           (Male) ()         2015
#
#                    Department DateAcquired    URL  ThumbnailURL  Height (cm)  \
# 65      Architecture & Design   1980-01-08   True          True      34.9251
# 66      Architecture & Design   2000-01-19   True          True      63.5001
# 76      Architecture & Design   1980-01-08   True          True      72.4000
# 107     Architecture & Design   1990-01-17   True          True      41.3000
# 110     Architecture & Design   1966-01-01   True          True      37.5000
# 111     Architecture & Design   1966-01-01   True          True      37.5000
# 112     Architecture & Design   1966-01-01   True          True      71.1000
# 113     Architecture & Design   1966-01-01   True          True      71.0000
# 151     Architecture & Design   1992-01-15   True          True     121.0000
# 154     Architecture & Design   1992-01-15   True          True     113.0000
# 160     Architecture & Design   1988-04-27   True          True      52.1000
# 161     Architecture & Design   1988-04-27   True          True      30.4801
# 162     Architecture & Design   1988-04-27   True          True      30.4801
# 163     Architecture & Design   1988-04-27   True          True      30.4801
# 164     Architecture & Design   1988-04-27   True          True      30.4801
# 178     Architecture & Design   1947-06-17   True          True      57.2000
# 195     Architecture & Design   1991-06-04   True          True     100.3000
# 196     Architecture & Design   1991-06-04   True          True      99.1000
# 238     Architecture & Design   1999-06-30   True          True     101.6000
# 240     Architecture & Design   1999-06-30   True          True     101.6000
# 241     Architecture & Design   1999-06-30   True          True     101.6002
# 242     Architecture & Design   1999-06-30   True          True      63.5001
# 253     Architecture & Design   1984-10-30   True          True      21.0000
# 254     Architecture & Design   1984-10-30   True          True      90.0000
# 266     Architecture & Design   1984-10-30   True          True      31.1000
# 267     Architecture & Design   1984-10-30   True          True      21.9075
# 268     Architecture & Design   1984-10-30   True          True      25.1000
# 320     Architecture & Design   1996-02-25   True          True      46.4000
# 322     Architecture & Design   1996-09-25   True          True      46.0000
# 329     Architecture & Design   1996-09-25   True          True      30.8000
# ...                       ...          ...    ...           ...          ...
# 152210  Architecture & Design   2016-06-10  False         False      15.0000
# 152211  Architecture & Design   2016-06-10  False         False      15.0000
# 152212  Architecture & Design   2016-06-10  False         False      15.0000
# 152213  Architecture & Design   2016-06-10  False         False      15.0000
# 152214  Architecture & Design   2016-06-10  False         False      15.0000
# 152215  Architecture & Design   2016-06-10  False         False      15.0000
# 152216  Architecture & Design   2016-06-10  False         False      15.0000
# 152217  Architecture & Design   2016-06-10  False         False      15.0000
# 152218  Architecture & Design   2016-06-10  False         False      15.0000
# 152219  Architecture & Design   2016-06-10  False         False      15.0000
# 152220  Architecture & Design   2016-06-10  False         False      15.0000
# 152221  Architecture & Design   2016-06-10  False         False      15.0000
# 152222  Architecture & Design   2016-06-10  False         False      15.0000
# 152223  Architecture & Design   2016-06-10  False         False      15.0000
# 152224  Architecture & Design   2016-06-10  False         False      15.0000
# 152225  Architecture & Design   2016-06-10  False         False      15.0000
# 152226  Architecture & Design   2016-06-10  False         False      15.0000
# 152227  Architecture & Design   2016-06-10  False         False      15.0000
# 152228  Architecture & Design   2016-06-10  False         False      15.0000
# 152229  Architecture & Design   2016-06-10  False         False      15.0000
# 152230  Architecture & Design   2016-06-10  False         False      15.0000
# 152231  Architecture & Design   2016-06-10  False         False      15.0000
# 152232  Architecture & Design   2016-06-10  False         False      15.0000
# 152233  Architecture & Design   2016-06-10  False         False      15.0000
# 152234  Architecture & Design   2016-06-10  False         False      15.0000
# 152235  Architecture & Design   2016-06-10  False         False      15.0000
# 152236  Architecture & Design   2016-06-10  False         False      15.0000
# 152237  Architecture & Design   2016-06-10  False         False      15.0000
# 152238  Architecture & Design   2016-06-10  False         False      15.0000
# 152239  Architecture & Design   2016-06-10  False         False      15.0000
#
#         Width (cm)  YearAcquired
# 65        113.3477          1980
# 66         99.0602          2000
# 76         91.4000          1980
# 107        96.2000          1990
# 110        95.3000          1966
# 111        95.9000          1966
# 112        71.1000          1966
# 113       127.6000          1966
# 151        92.7000          1992
# 154        68.6000          1992
# 160        91.4000          1988
# 161        59.6901          1988
# 162        38.4176          1988
# 163        34.2901          1988
# 164        71.1201          1988
# 178        57.2000          1947
# 195       151.1000          1991
# 196       151.1000          1991
# 238        76.2000          1999
# 240        75.9000          1999
# 241        76.2002          1999
# 242        88.9002          1999
# 253        26.7000          1984
# 254        89.9000          1984
# 266        26.0000          1984
# 267        26.9876          1984
# 268        18.7000          1984
# 320        34.0000          1996
# 322        33.3000          1996
# 329        41.6000          1996
# ...            ...           ...
# 152210     15.0000          2016
# 152211     15.0000          2016
# 152212     15.0000          2016
# 152213     15.0000          2016
# 152214     15.0000          2016
# 152215     15.0000          2016
# 152216     15.0000          2016
# 152217     15.0000          2016
# 152218     15.0000          2016
# 152219     15.0000          2016
# 152220     15.0000          2016
# 152221     15.0000          2016
# 152222     15.0000          2016
# 152223     15.0000          2016
# 152224     15.0000          2016
# 152225     15.0000          2016
# 152226     15.0000          2016
# 152227     15.0000          2016
# 152228     15.0000          2016
# 152229     15.0000          2016
# 152230     15.0000          2016
# 152231     15.0000          2016
# 152232     15.0000          2016
# 152233     15.0000          2016
# 152234     15.0000          2016
# 152235     15.0000          2016
# 152236     15.0000          2016
# 152237     15.0000          2016
# 152238     15.0000          2016
# 152239     15.0000          2016
#
# [5354 rows x 11 columns]

# %%
artworks['Date'].head(10)
# Out:
# 0       1896
# 1       1987
# 2       1903
# 3       1980
# 4       1903
# 5    1976-77
# 6    1976-77
# 7    1976-77
# 8    1976-77
# 9    1976-77
# Name: Date, dtype: object

# %%
# Remove multiple nationalities, genders, and artists.
artworks.loc[artworks['Gender'].str.contains('\) \('), 'Gender'] = '\(multiple_persons\)'
artworks.loc[artworks['Nationality'].str.contains('\) \('), 'Nationality'] = '\(multiple_nationalities\)'
artworks.loc[artworks['Artist'].str.contains(','), 'Artist'] = 'Multiple_Artists'

# Convert dates to start date, cutting down number of distinct examples.
artworks['Date'] = pd.Series(artworks.Date.str.extract(
    '([0-9]{4})', expand=False))[:-1]

# Final column drops and NA drop.
X = artworks.drop(['Department', 'DateAcquired', 'Artist', 'Nationality', 'Date'], 1)

# %%
# Create dummies separately.
artists = pd.get_dummies(artworks.Artist)
nationalities = pd.get_dummies(artworks.Nationality)
dates = pd.get_dummies(artworks.Date)

# Concat with other variables, but artists slows this wayyyyy down so we'll keep it out for now
X = pd.get_dummies(X, sparse=True)
X = pd.concat([X, nationalities, dates], axis=1)

Y = artworks.Department

# %%
Y
# Out:
# 0              Architecture & Design
# 1              Architecture & Design
# 2              Architecture & Design
# 3              Architecture & Design
# 4              Architecture & Design
# 5              Architecture & Design
# 6              Architecture & Design
# 7              Architecture & Design
# 8              Architecture & Design
# 9              Architecture & Design
# 10             Architecture & Design
# 11             Architecture & Design
# 12             Architecture & Design
# 13             Architecture & Design
# 14             Architecture & Design
# 15             Architecture & Design
# 16             Architecture & Design
# 17             Architecture & Design
# 18             Architecture & Design
# 19             Architecture & Design
# 20             Architecture & Design
# 21             Architecture & Design
# 22             Architecture & Design
# 23             Architecture & Design
# 24             Architecture & Design
# 25             Architecture & Design
# 26             Architecture & Design
# 27             Architecture & Design
# 28             Architecture & Design
# 29             Architecture & Design
#                      ...
# 152512                   Photography
# 152513                   Photography
# 152514                   Photography
# 152515                   Photography
# 152516                   Photography
# 152517                   Photography
# 152518                   Photography
# 152519                   Photography
# 152520                   Photography
# 152521                   Photography
# 152522                   Photography
# 152523                   Photography
# 152524                   Photography
# 152525                   Photography
# 152526                   Photography
# 152527                   Photography
# 152528                   Photography
# 152529                   Photography
# 152530                   Photography
# 152531                   Photography
# 152532                   Photography
# 152533                   Photography
# 152534                   Photography
# 152535                   Photography
# 152536                   Photography
# 152537    Prints & Illustrated Books
# 152538    Prints & Illustrated Books
# 152539    Prints & Illustrated Books
# 152540    Prints & Illustrated Books
# 152541    Prints & Illustrated Books
# Name: Department, Length: 105817, dtype: object

# %%
# Alright! We've done our prep, let's build the model.
# Neural networks are hugely computationally intensive.
# This may take several minutes to run.

# Import the model.
from sklearn.neural_network import MLPClassifier


import time
start_time = time.time()

# Establish and fit the model, with a single, 1000 perceptron layer.
mlp = MLPClassifier(hidden_layer_sizes=(1000,))
mlp.fit(X, Y)

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 105.47419905662537 seconds ---

# %%
import time
start_time = time.time()

print(mlp.score(X, Y))

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# 0.5813054613152896
#
# --- 2.693662405014038 seconds ---

# %%
Y.value_counts()/len(Y)
# Out:
# Prints & Illustrated Books    0.521192
# Photography                   0.228186
# Architecture & Design         0.113148
# Drawings                      0.103717
# Painting & Sculpture          0.033756
# Name: Department, dtype: float64

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(mlp, X, Y, cv=5)
# Out:
# array([0.57890012, 0.61883387, 0.51859377, 0.5554768 , 0.47930252])

# %% [markdown]
# Now we got a lot of information from all of this. Firstly we can see that the model seems to overfit, though there is still so remaining performance when validated with cross validation. This is a feature of neural networks that aren't given enough data for the number of features present. _Neural networks, in general, like_ a lot _of data_. You may also have noticed something also about neural networks: _they can take a_ long _time to run_. Try increasing the layer size by adding a zero. Feel free to interrupt the kernel if you don't have time...
#
# Also note that we created bools for artist's name but left them out. Both of the above points are the reason for that. It would take much longer to run and it would be much more prone to overfitting.

# %% [markdown]
# ## Model parameters
#
# Now, before we move on and let you loose with some tasks to work on the model, let's go over the parameters.
#
# We included one parameter: hidden layer size. Remember in the previous lesson, when we talked about layers in a neural network. This tells us how many and how big to make our layers. Pass in a tuple that specifies each layer's size. Our network is 1000 neurons wide and one layer. (100, 4, ) would create a network with two layers, one 100 wide and the other 4.
#
# How many layers to include is determined by two things: computational resources and cross validation searching for convergence. It's generally less than the number of input variables you have.
#
# You can also set an alpha. Neural networks like this use a regularization parameter that penalizes large coefficients just like we discussed in the advanced regression section. Alpha scales that penalty.
#
# Lastly, we'll discuss the activation function. The activation function determines whether the output from an individual perceptron is binary or continuous. By default this is a 'relu', or 'rectified linear unit function' function. In the exercise we went through earlier we used this binary function, but we discussed the _sigmoid_ as a reasonable alternative. The _sigmoid_ (called 'logistic' by SKLearn because it's a 'logistic sigmoid function') allows for continuous variables between 0 and 1, which allows for a more nuanced model. It does come at the cost of increased computational complexity.
#
# If you want to learn more about these, study [activation functions](https://en.wikipedia.org/wiki/Activation_function) and [multilayer perceptrons](https://en.wikipedia.org/wiki/Multilayer_perceptron). The [Deep Learning](http://www.deeplearningbook.org/) book referenced earlier goes into great detail on the linear algebra involved.
#
# You could also just test the models with cross validation. Unless neural networks are your specialty cross validation should be sufficient.
#
# For the other parameters and their defaults, check out the [MLPClassifier documentaiton](http://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html#sklearn.neural_network.MLPClassifier).

# %% [markdown]
# ## Drill: Playing with layers
#
# Now it's your turn. Using the space below, experiment with different hidden layer structures. You can try this on a subset of the data to improve runtime. See how things vary. See what seems to matter the most. Feel free to manipulate other parameters as well. It may also be beneficial to do some real feature selection work...

# %%
# Your code here. Experiment with hidden layers to build your own model.

# %%
#artworks = pd.read_csv('https://media.githubusercontent.com/media/MuseumofModernArt/collection/master/Artworks.csv')

# %%
artworks.head()
# Out:
#                      Artist Nationality  Gender  Date             Department  \
# 0               Otto Wagner  (Austrian)  (Male)  1896  Architecture & Design
# 1  Christian de Portzamparc    (French)  (Male)  1987  Architecture & Design
# 2                Emil Hoppe  (Austrian)  (Male)  1903  Architecture & Design
# 3           Bernard Tschumi          ()  (Male)  1980  Architecture & Design
# 4                Emil Hoppe  (Austrian)  (Male)  1903  Architecture & Design
#
#   DateAcquired   URL  ThumbnailURL  Height (cm)  Width (cm)  YearAcquired
# 0   1996-04-09  True          True      48.6000    168.9000          1996
# 1   1995-01-17  True          True      40.6401     29.8451          1995
# 2   1997-01-15  True          True      34.3000     31.8000          1997
# 3   1995-01-17  True          True      50.8000     50.8000          1995
# 4   1997-01-15  True          True      38.4000     19.1000          1997

# %% [markdown]
# First, I will create subsets to reduce the runtime and compare the full dataset to the reduced dataset for several configurations of the neural network.

# %%
art_50 = artworks.sample(frac=0.5)

X_50 = art_50.drop(['Department', 'DateAcquired', 'Artist', 'Nationality', 'Date'], 1)

artists = pd.get_dummies(art_50.Artist)
nationalities = pd.get_dummies(art_50.Nationality)
dates = pd.get_dummies(art_50.Date)

X_50 = pd.get_dummies(X_50, sparse=True)
X_50 = pd.concat([X_50, nationalities, dates], axis=1)

Y_50 = art_50.Department

# %%
art_10 = artworks.sample(frac=0.1)

X_10 = art_10.drop(['Department', 'DateAcquired', 'Artist', 'Nationality', 'Date'], 1)

artists = pd.get_dummies(art_10.Artist)
nationalities = pd.get_dummies(art_10.Nationality)
dates = pd.get_dummies(art_10.Date)

X_10 = pd.get_dummies(X_10, sparse=True)
X_10 = pd.concat([X_10, nationalities, dates], axis=1)

Y_10 = art_10.Department

# %%
# Create a function to fit and cross validation:
def run_mlp(X,Y, sizes):
    mlp = MLPClassifier(hidden_layer_sizes=(sizes))
    mlp.fit(X, Y)
    print('Hidden Layer Sizes: {sizes}'.format(sizes=sizes))
    print('Accuracy: ',mlp.score(X, Y))
    scores = cross_val_score(mlp, X, Y, cv=5)
    print('Cross Val Scores: {scores}'.format(scores=scores))
    print('\nCross Val Mean: ',scores.mean())

# %% [markdown]
# # Test the neural net with different settings:

# %% [markdown]
# ## 2 layers of length 100 and 4:

# %%
# Import the model.
from sklearn.neural_network import MLPClassifier

import time
start_time = time.time()

# Test with the original data set:
run_mlp(X, Y, [100,4])

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [100, 4]
# Accuracy:  0.5211922469924493
# Cross Val Scores: [0.52116602 0.52116802 0.52119265 0.52121728 0.52121728]
# Cross Val Mean:  0.5211922484380136
#
# --- 53.598079204559326 seconds ---

# %%
import time
start_time = time.time()

run_mlp(X_50, Y_50, [100,4])

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [100, 4]
# Accuracy:  0.5222461631511303
# Cross Val Scores: [0.52225267 0.52220752 0.52220752 0.52220752 0.52235561]
# Cross Val Mean:  0.5222461692338147
#
# --- 38.10286021232605 seconds ---

# %%
import time
start_time = time.time()

run_mlp(X_10, Y_10, [100,4])

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [100, 4]
# Accuracy:  0.5317520317520318
# Cross Val Scores: [0.55004721 0.53163362 0.53141238 0.53191489 0.53169347]
# Cross Val Mean:  0.5353403145368477
#
# --- 16.16951274871826 seconds ---

# %% [markdown]
# With a network structure of [100,4], we can see that the accuracy of the network stays relatively the same across datasets. This is an interesting finding and not what I expected, since neural nets tend to need a lot of data.
#
# None of the networks are overfitting by much either.
#
# Perhaps the lack of data can be made up for by expanding the size of the hidden layers, so more analysis is being done despite having less data.

# %% [markdown]
# ## 3 layers of length 10:
# Let's test with a 3-layer structure to see what happens:

# %%
import time
start_time = time.time()

# Test with the original data set:
run_mlp(X, Y, [10,10,10])

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [10, 10, 10]
# Accuracy:  0.6582874207357986
# Cross Val Scores: [0.6106964  0.61264411 0.55195388 0.56185616 0.51384557]
#
# Cross Val Mean:  0.5701992247641375
#
# --- 150.14933276176453 seconds ---

# %%
import time
start_time = time.time()

run_mlp(X_50, Y_50, [10,10,10])

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [10, 10, 10]
# Accuracy:  0.6549104105239283
# Cross Val Scores: [0.61513748 0.63853714 0.63778114 0.62256662 0.62898195]
#
# Cross Val Mean:  0.6286008657787081
#
# --- 48.0041983127594 seconds ---

# %%
import time
start_time = time.time()

run_mlp(X_10, Y_10, [10,10,10])

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [10, 10, 10]
# Accuracy:  0.6238896238896239
# Cross Val Scores: [0.58829084 0.61661945 0.5862069  0.53380615 0.62298959]
#
# Cross Val Mean:  0.5895825858082173
#
# --- 9.418059349060059 seconds ---

# %% [markdown]
# With a minimal network structure of **[10, 10, 10]**, we see that the accuracy drops from 0.66 to 0.62 to 0.59 as we reduce the dataset. The difference between the full dataset and the 50% dataset is not as big a difference as the 10% dataset. This shows us that although we see a benefit in reduced runtime, it may not be worth our while to reduce datasets in the future because the performance gets worse and worse in a non-linear manner.
#
# I have read advice online that says beyond 2-3 hidden layers, there tends not to be a big increase in performance.
#
# Let's test that theory by running 5 layers with 10 perceptrons each.

# %% [markdown]
# ## 5 layers of length 10:

# %%
import time
start_time = time.time()

# Test with the original data set:
run_mlp(X, Y, [10,10,10,10,10])

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [10, 10, 10, 10, 10]
# Accuracy:  0.6119999621988905
# Cross Val Scores: [0.56864783 0.64675865 0.50630818 0.50642661 0.47093847]
#
# Cross Val Mean:  0.5398159491844005
#
# --- 105.76184105873108 seconds ---

# %%
import time
start_time = time.time()

run_mlp(X_50, Y_50, [10,10,10,10,10])

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [10, 10, 10, 10, 10]
# Accuracy:  0.6650223028653511
# Cross Val Scores: [0.54672588 0.63683614 0.63674164 0.62559063 0.63815105]
#
# Cross Val Mean:  0.6168090668546738
#
# --- 52.31616759300232 seconds ---

# %%
import time
start_time = time.time()

run_mlp(X_10, Y_10, [10,10,10,10,10])

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [10, 10, 10, 10, 10]
# Accuracy:  0.5562275562275563
# Cross Val Scores: [0.60812087 0.55146364 0.5578649  0.49881797 0.55534532]
#
# Cross Val Mean:  0.5543225401389625
#
# --- 9.831654071807861 seconds ---

# %% [markdown]
# 3 layers of [10,10,10] gave scores of 0.65, 0.62, and 0.59. Increasing to 5 layers gave scores of 0.61, 0.66, and 0.55. This shows that adding more layers doesn't necessarily improve results. It seems like the size of the layers is more important.
#
# Here we see that the 50% reduced dataset actually performed the best, despite some overfitting. This finding would contradict the earlier finding that more data produces better results, but this finding also uses 5 small hidden layers, when standard practice is to use fewer larger layers.

# %% [markdown]
# ## Neural Net with 1 layer, higher length:
# Let's expand the size of the hidden layers, but decrease the number to the minimum (1).

# %%
import time
start_time = time.time()

# Test with the original data set:
run_mlp(X, Y, [150])

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [150]
# Accuracy:  0.4196301161439088
# Cross Val Scores: [0.52385902 0.58821584 0.53087936 0.56951139 0.53076269]
#
# Cross Val Mean:  0.5486456597002354
#
# --- 63.540528297424316 seconds ---

# %%
import time
start_time = time.time()

run_mlp(X_50, Y_50, [150])

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [150]
# Accuracy:  0.5033076283359794
# Cross Val Scores: [0.5803099  0.62726757 0.55722522 0.60718336 0.58899707]
#
# Cross Val Mean:  0.5921966249896583
#
# --- 24.53026056289673 seconds ---

# %%
import time
start_time = time.time()

run_mlp(X_10, Y_10, [150])

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [150]
# Accuracy:  0.5753165753165753
# Cross Val Scores: [0.56421152 0.51935788 0.57817667 0.57635934 0.49858089]
#
# Cross Val Mean:  0.5473372595124187
#
# --- 5.443480491638184 seconds ---

# %% [markdown]
# Now, we have our worst set of scores yet at 0.48, 0.59, and 0.54. Perhaps more than one layer is needed, or if there is only one layer, it must be much larger than this.

# %% [markdown]
# ## NN with 1 layer, size 2:
# Lets see what happens when we continue with the minimum of 1 layer, but this time with a minimal size of 2. Will the score get even worse?

# %%
import time
start_time = time.time()
# Test with the original data set:
run_mlp(X, Y, [2])
print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [2]
# Accuracy:  0.5211922469924493
# Cross Val Scores: [0.52116602 0.52116802 0.5211454  0.52121728 0.52121728]
#
# Cross Val Mean:  0.521182797982029
#
# --- 29.751643896102905 seconds ---

# %%
import time
start_time = time.time()
run_mlp(X_50, Y_50, [2])
print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [150]
# Accuracy:  0.5033076283359794
# Cross Val Scores: [0.5803099  0.62726757 0.55722522 0.60718336 0.58899707]
#
# Cross Val Mean:  0.5921966249896583
#
# --- 24.53026056289673 seconds ---

# %%
import time
start_time = time.time()

run_mlp(X_10, Y_10, [2])

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [150]
# Accuracy:  0.5753165753165753
# Cross Val Scores: [0.56421152 0.51935788 0.57817667 0.57635934 0.49858089]
#
# Cross Val Mean:  0.5473372595124187
#
# --- 5.443480491638184 seconds ---

# %% [markdown]
# With scores of 0.52, 0.59, and 0.55, these scores with hidden layers=[2] are comparable with the scores of hidden layers=[150].

# %% [markdown]
# ## NN with 1 layer, size 1000:
# Let's see when we keep the minimum of 1 layer, but expand the size drastically.
#
# ... computer died 2 times :(

# %%
import time
start_time = time.time()
# Test with the original data set:
run_mlp(X, Y, [1000])
print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.0 seconds ---

# %%
import time
start_time = time.time()
run_mlp(X_50, Y_50, [1000])
print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [1000]
# Accuracy:  0.5791751719966735
# Cross Val Scores: [0.60994047 0.27978834 0.64987715 0.62234193 0.61036015]
#
# Cross Val Mean:  0.5544616082699998
#
# --- 322.0889313220978 seconds ---

# %%
import time
start_time = time.time()

run_mlp(X_10, Y_10, [1000])

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# Hidden Layer Sizes: [1000]
# Accuracy:  0.2373842373842374
# Cross Val Scores: [0.5434372  0.5879017  0.53497164 0.24007561 0.19848771]
#
# Cross Val Mean:  0.42097477557563134
#
# --- 33.0052604675293 seconds ---

# %% [markdown]
# When we expanded the layer, the full dataset died twice.
#
# The 50% reduced dataset was overfitting, with the accuracy was reduced to 0.55.
#
# The 10% dataset was dramatically underfitting, which is interesting. This shows us that although large datasets are preferred, they may lead to overfitting.

# %% [markdown]
# Let's perform some basic feature selection to see if we can improve this algorithm. Now that we are trying to make a robust algorithm (instead of just tinkering with variables) we will split our data into training and testing datasets to see the accuracy.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,
                                                    test_size=0.3,
                                                    random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

from sklearn.feature_selection  import SelectFromModel

from sklearn.svm  import LinearSVC

from sklearn.ensemble  import RandomForestClassifier

# %%
import time
start_time = time.time()

pipe = Pipeline([
    ('feat', VarianceThreshold()),
    ('mlp', MLPClassifier())
])

param_grid = [
    {
        'feat__threshold': [(.8 * (1 - .8)),(.6 * (1 - .6)),(.4 * (1 - .4))],
        'mlp__hidden_layer_sizes': [[10,10,10],[1000]]
    }
]

grid = GridSearchCV(pipe, cv=3, n_jobs=1, param_grid=param_grid)
grid.fit(X_train, Y_train)
print(grid.best_params_)
prediction = grid.predict(X_test)
print(accuracy_score(Y_test, prediction))

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# {'feat__threshold': 0.24, 'mlp__hidden_layer_sizes': [10, 10, 10]}
# 0.5192465192465192
#
# --- 230.45436120033264 seconds ---

# %% [markdown]
# With a validation score of 0.52, feature selection via variance threshold did not drastically improve our results. We used the hidden layer structures that produced the 2 best scores from earlier in the notebook to test this.
#
# When using a hidden layer structure of [10,10,10] on the full dataset, the score was 0.57.
# `strange`
#
# ## SelectKBest
# We will try one more method of feature reduction -- SelectKBest.

# %%
import time
start_time = time.time()

pipe = Pipeline([
    ('feat', SelectKBest(k=100)),
    ('mlp', MLPClassifier(hidden_layer_sizes = [10,10,10]))
])

pipe.fit(X_train, Y_train)
prediction = pipe.predict(X_test)
print(accuracy_score(Y_test, prediction))

print("\n--- %s seconds ---" % (time.time() - start_time))
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\feature_selection\univariate_selection.py:113: UserWarning: Features [ 49  62  75  85  94  95 109 119 122 123 125 315] are constant.
#   UserWarning)
# C:\Anaconda3\lib\site-packages\sklearn\feature_selection\univariate_selection.py:114: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# 0.5767340767340767

# %% [markdown]
# Alright! Using SelectKBest with 100 features, we were able to obtain a score of  0.58. This is still not great, but a significant improvement from the values around 0.54 that all the other models were obtaining.

# %% [markdown]
# ## Conclusion
#
# I have experimented with hidden layer structures, dataset sizes, and feature selection to classify this set using neural nets. With the full feature dataset, I generally found that including all datapoints led to greater accuracy scores, but this was not always the case. Sometimes including all the datapoints led to overfitting, so I will make a note to be cautious about this in the future. When the structure was very small and minimal, I saw more consistency in results between the differently-sized datasets.
#
# Given that there were so many categorical features conveying little information per feature, I thought that setting a variance threshold to reduce the feature set would be beneficial. However, even after iterating through multiple threshold values and hidden layer structure using GridSearch, I did not see an increase in performance. I did, however, see a significant increase in performance when using SelectKBest. I will continue using these methods as I learn more about data science.
